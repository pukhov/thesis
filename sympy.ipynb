# %%
# from joblib import Parallel, delayed

import numpy as np
import matplotlib.pylab as plt
# %matplotlib inline

import sympy
import scipy
import scipy.optimize
import scipy.special
import scipy.misc
import scipy.integrate as integrate
import scipy.interpolate as interpolate

import seaborn as sns
sns.set()

EPS = 1e-9

from tqdm import tqdm as tqdm

from sympy import *

# %%
    plt.rcParams["figure.figsize"] = (16, 9)

# %%
import mpmath

# %%
mpmath.quad(lambda x : -x, [x1, x2])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-c559c5b87ce4> in <module>()
# ----> 1 mpmath.quad(lambda x : -x, [x1, x2])
#
# NameError: name 'x1' is not defined

# %%
from sympy.abc import a, b, x, s, m
from sympy import integrate, sqrt

from sympy import init_printing

# %%
init_printing()

# %%
expr
# Out:
# <module 'sympy.core.expr' from '/home/alexander/.local/lib/python3.6/site-packages/sympy/core/expr.py'>

# %%
k, c, r, p = symbols('k c r p') # r (radius), t (angle theta)
F,  g = symbols('F g', cls=Function)
g = f(x**2,y)**k
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-c214ffd88c03> in <module>()
#       1 k, c, r, p = symbols('k c r p') # r (radius), t (angle theta)
#       2 F, g = symbols('F g', cls=Function)
# ----> 3 g = f(x**2,y)**k
#
# NameError: name 'f' is not defined

# %%
a, b, x  = symbols('a b x')

# %%
F = a * x + b

# %%
diff(F, x, x)
# Out:
# 0

# %%
sympy.simplify(-k * (c - 1) + c * (c - 1) + k * 2 * (c - 1) * c - k * (c - 1) * c + c * c)
# Out:
#  2        2
# c ⋅k + 2⋅c  - 2⋅c⋅k - c + k

# %%
(k+2) c^2 - (2k + 1) c + k
# Out:
#   File "<ipython-input-19-f04e07e6e479>", line 1
#     (k+2) c^2 - (2k + 1) c + k
#           ^
# SyntaxError: invalid syntax

# %%
24 x - 21
# Out:
#   File "<ipython-input-20-ba8fe6f2e63b>", line 1
#     24 x - 21
#        ^
# SyntaxError: invalid syntax

# %%
g = F(c)**(k - 1) * (1 - F(c - r + p))

# %%
sympy.simplify(diff(log(g), c, c))
# Out:
#
#           ⎛                   d               ⎛ d        ⎞│            ⎞
# - (k - 1)⋅⎜(F(c + p - r) - 1)⋅──(F(c)) + F(c)⋅⎜───(F(ξ₁))⎟│            ⎟⋅(F(c
#           ⎝                   dc              ⎝dξ₁       ⎠│ξ₁=c + p - r⎠
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                                  ⎛                     2
#               d                  ⎜                    d            d        ⎛
# + p - r) - 1)⋅──(F(c)) + (k - 1)⋅⎜(F(c + p - r) - 1)⋅───(F(c)) + 2⋅──(F(c))⋅⎜─
#               dc                 ⎜                     2           dc       ⎝d
#                                  ⎝                   dc
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                        ⎞
# d        ⎞│            ⎟                           ⎛
# ──(F(ξ₁))⎟│            ⎟⋅(F(c + p - r) - 1)⋅F(c) - ⎜(k - 1)⋅(F(c + p - r) - 1)
# ξ₁       ⎠│ξ₁=c + p - r⎟                           ⎝
#                        ⎠
# ──────────────────────────────────────────────────────────────────────────────
#                               2  2
#             (F(c + p - r) - 1) ⋅F (c)
#
#
#  d               ⎛ d        ⎞│            ⎞      ⎛ d        ⎞│
# ⋅──(F(c)) + F(c)⋅⎜───(F(ξ₁))⎟│            ⎟⋅F(c)⋅⎜───(F(ξ₁))⎟│             + (
#  dc              ⎝dξ₁       ⎠│ξ₁=c + p - r⎠      ⎝dξ₁       ⎠│ξ₁=c + p - r
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                         ⎛  2        ⎞│
#                    2    ⎜ d         ⎟│
# F(c + p - r) - 1)⋅F (c)⋅⎜────(F(ξ₁))⎟│
#                         ⎜   2       ⎟│
#                         ⎝dξ₁        ⎠│ξ₁=c + p - r
# ──────────────────────────────────────────────────

# %%
F.assumptions0

# %%
sympy.simplify(diff(g, c))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-d21c37e6596e> in <module>()
# ----> 1 sympy.simplify(diff(g, c)).subs(F, ax + b)
#
# NameError: name 'ax' is not defined

# %%
diff()
# Out:
#    ⎛                                          ⎛         3/2               ____
#    ⎜    _______   3⋅(m - s)       _______   4⋅⎝2⋅(m - s)    - 3⋅(m - s)⋅╲╱ m +
# √2⋅⎜6⋅╲╱ m - s  + ───────── - 9⋅╲╱ m + s  + ──────────────────────────────────
#    ⎜                _______                                          s
#    ⎝              ╲╱ m + s
# ──────────────────────────────────────────────────────────────────────────────
#                                                  2
#                                              12⋅s
#
# ___          3/2⎞⎞
#  s  + (m + s)   ⎠⎟
# ─────────────────⎟
#                  ⎟
#                  ⎠
# ──────────────────

# %%
expr = integrate(2 * 1 / ((b - a)**2) *(1 - sqrt(2*x)) * (x - a), (x, a, b))
expr = expr.subs(a, m - s)
expr = expr.subs(b, m + s)
expr = sympy.simplify(expr)

# %%
expr
# Out:
#               5/2             2                        3/2
# - 8⋅√2⋅(m - s)    + 15⋅(m - s)  + 20⋅√2⋅(m - s)⋅(m + s)    - 30⋅(m - s)⋅(m + s
# ──────────────────────────────────────────────────────────────────────────────
#                                                          2
#                                                      60⋅s
#
#                  5/2             2
# ) - 12⋅√2⋅(m + s)    + 15⋅(m + s)
# ──────────────────────────────────

# %%
f = lambdify((m, s), expr, 'numpy')

x = np.linspace(0.04, 0.09, 100)
y = np.linspace(0.01, 0.03, 100)

xv, yv = np.meshgrid(x, y)

plt.title('Value of Integral')
plt.xlabel("Mean = m")
plt.ylabel("Range = s")
CS = plt.contour(x, y, f(xv, yv), 7, colors='k', ) # CS is the ContourSet
plt.clabel(CS, inline=20, fontsize=10)
# Out:
# <a list of 8 text.Text objects>

# %%
expr

f(0.5, 0.2)

f = lambdify((x, y), sqrt(x**2 + y**2), 'numpy')

f(2, 4)

expr

sympy.plotting.plot3d(expr, (s, 0.03, 0.07), (m, 0, 0.02), )

sympy.function

type(expr_2)

expr(m, s)

expr_2

expr_2 = sympy.simplify(integrate(2 / ((2*s)**2) *(1 - sqrt(2*x)) * (x - m + s), (x, m-s, m+s)))

# %%
k, c, r, p = symbols('k c r p') # r (radius), t (angle theta)
F, f, g = symbols('F f g', cls=Function)

# %%
F = x**1.5
f = diff(F, x)

# %%
Integral(x**a*exp(-x), (x, 0, oo)).subs(x,  log(x))
# Out:
# ∞
# ⌠
# ⎮  a  -x
# ⎮ x ⋅ℯ   dx
# ⌡
# 0

# %%
F = integrate(integrate(x, , x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-97-5a81e8804e62> in <module>()
# ----> 1 F = integrate(g, x)
#
# ~/.local/lib/python3.6/site-packages/sympy/integrals/integrals.py in integrate(*args, **kwargs)
#    1289     risch = kwargs.pop('risch', None)
#    1290     manual = kwargs.pop('manual', None)
# -> 1291     integral = Integral(*args, **kwargs)
#    1292
#    1293     if isinstance(integral, Integral):
#
# ~/.local/lib/python3.6/site-packages/sympy/integrals/integrals.py in __new__(cls, function, *symbols, **assumptions)
#      73             return function._eval_Integral(*symbols, **assumptions)
#      74
# ---> 75         obj = AddWithLimits.__new__(cls, function, *symbols, **assumptions)
#      76         return obj
#      77
#
# ~/.local/lib/python3.6/site-packages/sympy/concrete/expr_with_limits.py in __new__(cls, function, *symbols, **assumptions)
#     384
#     385         obj = Expr.__new__(cls, **assumptions)
# --> 386         arglist = [orientation*function]
#     387         arglist.extend(limits)
#     388         obj._args = tuple(arglist)
#
# TypeError: unsupported operand type(s) for *: 'int' and 'UndefinedFunction'

# %%
F
# Out:
#        2                              3.5
# - 0.5⋅x  + 0.6⋅x + 0.114285714285714⋅x

# %%
h  = sympy.integrate(1 - F)
h = h.subs(x, 1) - h

h = sympy.factor(h)
h = sympy.simplify(h)

h
# Out:
#               2.5
# -1.0⋅x + 0.4⋅x    + 0.6

# %%
plot(h, (x, 0, 1))

# %%
f.subs(x, x+c) * F
# Out:
#      1.5        0.5
# 1.5⋅x   ⋅(c + x)

# %%
sympy.integrate(f.subs(x,  x+c) * F, x)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-88-17486f22f5f3> in <module>()
# ----> 1 sympy.integrate(f.subs(x,  x+c) * F, x)
#
# ~/.local/lib/python3.6/site-packages/sympy/integrals/integrals.py in integrate(*args, **kwargs)
#    1293     if isinstance(integral, Integral):
#    1294         return integral.doit(deep=False, meijerg=meijerg, conds=conds,
# -> 1295                              risch=risch, manual=manual)
#    1296     else:
#    1297         return integral
#
# ~/.local/lib/python3.6/site-packages/sympy/integrals/integrals.py in doit(self, **hints)
#     484                     function, xab[0],
#     485                     meijerg=meijerg1, risch=risch, manual=manual,
# --> 486                     conds=conds)
#     487                 if antideriv is None and meijerg1 is True:
#     488                     ret = try_meijerg(function, xab)
#
# ~/.local/lib/python3.6/site-packages/sympy/integrals/integrals.py in _eval_integral(self, f, x, meijerg, risch, manual, conds)
#     892                 try:
#     893                     if conds == 'piecewise':
# --> 894                         h = heurisch_wrapper(g, x, hints=[])
#     895                     else:
#     896                         h = heurisch(g, x, hints=[])
#
# ~/.local/lib/python3.6/site-packages/sympy/integrals/heurisch.py in heurisch_wrapper(f, x, rewrite, hints, mappings, retries, degree_offset, unnecessary_permutations)
#     128
#     129     res = heurisch(f, x, rewrite, hints, mappings, retries, degree_offset,
# --> 130                    unnecessary_permutations)
#     131     if not isinstance(res, Basic):
#     132         return res
#
# ~/.local/lib/python3.6/site-packages/sympy/integrals/heurisch.py in heurisch(f, x, rewrite, hints, mappings, retries, degree_offset, unnecessary_permutations)
#     673     else:
#     674         if retries >= 0:
# --> 675             result = heurisch(f, x, mappings=mappings, rewrite=rewrite, hints=hints, retries=retries - 1, unnecessary_permutations=unnecessary_permutations)
#     676
#     677             if result is not None:
#
# ~/.local/lib/python3.6/site-packages/sympy/integrals/heurisch.py in heurisch(f, x, rewrite, hints, mappings, retries, degree_offset, unnecessary_permutations)
#     656
#     657     if not (F.free_symbols - set(V)):
# --> 658         solution = _integrate('Q')
#     659
#     660         if solution is None:
#
# ~/.local/lib/python3.6/site-packages/sympy/integrals/heurisch.py in _integrate(field)
#     647         except ValueError:
#     648             raise PolynomialError
# --> 649         solution = solve_lin_sys(numer.coeffs(), coeff_ring, _raw=False)
#     650
#     651         if solution is None:
#
# ~/.local/lib/python3.6/site-packages/sympy/polys/solvers.py in solve_lin_sys(eqs, ring, _raw)
#      37
#      38     # transform from equations to matrix form
# ---> 39     matrix = eqs_to_matrix(eqs, ring)
#      40
#      41     # solve by row-reduction
#
# ~/.local/lib/python3.6/site-packages/sympy/polys/solvers.py in eqs_to_matrix(eqs, ring)
#      19     for j, e_j in enumerate(eqs):
#      20         for i, x_i in enumerate(xs):
# ---> 21             M[j, i] = e_j.coeff(x_i)
#      22         M[j, -1] = -e_j.coeff(1)
#      23
#
# ~/.local/lib/python3.6/site-packages/sympy/polys/rings.py in coeff(self, element)
#    1712                 monom, coeff = terms[0]
#    1713                 if coeff == self.ring.domain.one:
# -> 1714                     return self._get_coeff(monom)
#    1715
#    1716         raise ValueError("expected a monomial, got %s" % element)
#
# ~/.local/lib/python3.6/site-packages/sympy/polys/rings.py in _get_coeff(self, expv)
#    1678
#    1679     def _get_coeff(self, expv):
# -> 1680         return self.get(expv, self.ring.domain.zero)
#    1681
#    1682     def coeff(self, element):
#
# KeyboardInterrupt:

# %%
h
# Out:
#  2
# x        1
# ── - x + ─
# 2        2
